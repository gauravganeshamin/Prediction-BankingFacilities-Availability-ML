# %%
import pandas as pd
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import warnings
import tensorflow as tf
tf.__version__
warnings.filterwarnings('ignore')

# %%
loan_df=pd.read_csv('customer_loans.csv')
loan_df.head(5)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          27          70000              MORTGAGE               11.0
# 1          32          62000                  RENT                5.0
# 2          25          57000                  RENT                3.0
# 3          33          34000                  RENT                4.0
# 4          35          62000              MORTGAGE               15.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0           PERSONAL          C       3000            NaN
# 1            MEDICAL          C      15000          12.99
# 2            MEDICAL          A       6850            NaN
# 3            MEDICAL          D      10000          15.33
# 4  DEBTCONSOLIDATION          D      10000          15.33
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length  \
# 0                 0.04                         Y                           8
# 1                 0.24                         Y                           6
# 2                 0.12                         N                           4
# 3                 0.29                         Y                           8
# 4                 0.16                         N                          10
#
#    loan_status
# 0            0
# 1            0
# 2            0
# 3            1
# 4            1

# %% [markdown]
# ## Data Preprocessing Steps

# %%
loan_df.shape
# Out:
# (10000, 12)

# %%
loan_df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length', 'loan_status'],
#       dtype='object')

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  10000 non-null  int64
#  1   person_income               10000 non-null  int64
#  2   person_home_ownership       10000 non-null  object
#  3   person_emp_length           9709 non-null   float64
#  4   loan_intent                 10000 non-null  object
#  5   loan_grade                  10000 non-null  object
#  6   loan_amnt                   10000 non-null  int64
#  7   loan_int_rate               9015 non-null   float64
#  8   loan_percent_income         10000 non-null  float64
#  9   cb_person_default_on_file   10000 non-null  object
#  10  cb_person_cred_hist_length  10000 non-null  int64
#  11  loan_status                 10000 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 937.6+ KB

# %%
loan_df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  10000.000000   1.000000e+04        9709.000000  10000.000000
# mean      27.658300   6.656156e+04           4.794727   9637.337500
# std        6.274032   5.570718e+04           4.216092   6425.962537
# min       20.000000   6.000000e+03           0.000000    500.000000
# 25%       23.000000   3.879875e+04           2.000000   5000.000000
# 50%       26.000000   5.503900e+04           4.000000   8000.000000
# 75%       30.000000   8.000000e+04           7.000000  12275.000000
# max      144.000000   2.039784e+06         123.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count    9015.000000         10000.000000                10000.000000
# mean       11.010956             0.169710                    5.758800
# std         3.249357             0.106394                    4.017043
# min         5.420000             0.000000                    2.000000
# 25%         7.900000             0.090000                    3.000000
# 50%        10.990000             0.150000                    4.000000
# 75%        13.470000             0.230000                    8.000000
# max        22.110000             0.770000                   30.000000
#
#         loan_status
# count  10000.000000
# mean       0.222900
# std        0.416213
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
loan_df.isnull().sum()
# Out:
# person_age                      0
# person_income                   0
# person_home_ownership           0
# person_emp_length             291
# loan_intent                     0
# loan_grade                      0
# loan_amnt                       0
# loan_int_rate                 985
# loan_percent_income             0
# cb_person_default_on_file       0
# cb_person_cred_hist_length      0
# loan_status                     0
# dtype: int64

# %%
loan_df["person_emp_length"].fillna(loan_df["person_emp_length"].median(), inplace=True)

# %%
loan_df["loan_int_rate"].fillna(loan_df["loan_int_rate"].median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b9e69425d986> in <module>()
# ----> 1 oan_df["loan_int_rate"].fillna(loan_df["loan_int_rate"].median(), inplace=True)
#
# NameError: name 'oan_df' is not defined

# %%
loan_df.isnull().sum()

# %%
loan_df.duplicated().sum()
# Out:
# 19

# %%
loan_df.drop_duplicates(inplace=True)

# %%
def find_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)]

# %%
likely_outlier_cols = ["person_age","person_income","person_emp_length","cb_person_cred_hist_length"]
for col in likely_outlier_cols:
    print(find_outliers(loan_df, col).shape)
# Out:
# (459, 12)
# (487, 12)
# (257, 12)
# (329, 12)

# %%
# box plot for continuous variables
plt.figure(figsize=(15,15))
loan_df[['person_age','person_income','person_emp_length','loan_amnt','loan_int_rate','loan_status','loan_percent_income','cb_person_cred_hist_length']].boxplot(vert=0)

# %%
def remove_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_range = Q1 - 1.5*IQR
    upper_range = Q3 + 1.5*IQR
    df[col] = np.where(df[col]>upper_range, upper_range, df[col])
    df[col] = np.where(df[col]<lower_range, lower_range, df[col])
    return df
for col in likely_outlier_cols:
    remove_outliers(loan_df, col)

# %%
# construct box plot for continuous variables
plt.figure(figsize=(15,15))
loan_df[['person_age','person_income','person_emp_length','loan_amnt','loan_int_rate','loan_status','loan_percent_income','cb_person_cred_hist_length']].boxplot(vert=0)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(loan_df.corr(), annot=True, cmap="RdBu")
plt.title("Correlations Between Variables", size=15)
plt.show()

# %%
loan_df.person_home_ownership = loan_df.person_home_ownership.str.replace('RENT', '0')
loan_df.person_home_ownership = loan_df.person_home_ownership.str.replace('MORTGAGE', '1')
loan_df.person_home_ownership = loan_df.person_home_ownership.str.replace('OWN', '2')
loan_df.person_home_ownership = loan_df.person_home_ownership.str.replace('OTHER', '3')

loan_df.loan_intent = loan_df.loan_intent.str.replace('EDUCATION', '0')
loan_df.loan_intent = loan_df.loan_intent.str.replace('MEDICAL', '1')
loan_df.loan_intent = loan_df.loan_intent.str.replace('VENTURE', '2')
loan_df.loan_intent = loan_df.loan_intent.str.replace('PERSONAL', '3')
loan_df.loan_intent = loan_df.loan_intent.str.replace('DEBTCONSOLIDATION', '4')
loan_df.loan_intent = loan_df.loan_intent.str.replace('HOMEIMPROVEMENT', '5')

loan_df.loan_grade = loan_df.loan_grade.str.replace('A', '0')
loan_df.loan_grade = loan_df.loan_grade.str.replace('B', '1')
loan_df.loan_grade = loan_df.loan_grade.str.replace('C', '2')
loan_df.loan_grade = loan_df.loan_grade.str.replace('D', '3')
loan_df.loan_grade = loan_df.loan_grade.str.replace('E', '4')
loan_df.loan_grade = loan_df.loan_grade.str.replace('F', '5')
loan_df.loan_grade = loan_df.loan_grade.str.replace('G', '6')

loan_df.cb_person_default_on_file = loan_df.cb_person_default_on_file.str.replace('N', '0')
loan_df.cb_person_default_on_file = loan_df.cb_person_default_on_file.str.replace('Y', '1')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
loan_dfx = loan_df.iloc[:,:-1].values
loan_dfy = loan_df.iloc[:,-1].values
loan_dfx[:, 2] = le.fit_transform(loan_dfx[:, 2])
loan_dfx[:, 4] = le.fit_transform(loan_dfx[:, 4])
loan_dfx[:, 5] = le.fit_transform(loan_dfx[:, 5])
loan_dfx[:, 9] = le.fit_transform(loan_dfx[:, 9])

# %%
loan_dfx
# Out:
# array([[27.0, 70000.0, 1, ..., 0.04, 1, 8.0],
#        [32.0, 62000.0, 0, ..., 0.24, 1, 6.0],
#        [25.0, 57000.0, 0, ..., 0.12, 0, 4.0],
#        ...,
#        [24.0, 60000.0, 1, ..., 0.04, 0, 4.0],
#        [27.0, 120000.0, 1, ..., 0.12, 0, 7.0],
#        [26.0, 51996.0, 1, ..., 0.35, 0, 3.0]], dtype=object)

# %%
loan_dfx[0]
# Out:
# array([27.0, 70000.0, 1, 11.0, 3, 2, 3000, nan, 0.04, 1, 8.0],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(loan_dfx,loan_dfy,test_size = 0.2,random_state =2)

# %%
Xtrain
# Out:
# array([[23.0, 45996.0, 2, ..., 0.22, 0, 3.0],
#        [30.0, 58000.0, 0, ..., 0.09, 0, 9.0],
#        [28.0, 50000.0, 3, ..., 0.08, 0, 10.0],
#        ...,
#        [24.0, 26400.0, 3, ..., 0.19, 0, 4.0],
#        [27.0, 127000.0, 0, ..., 0.17, 0, 5.0],
#        [25.0, 35000.0, 3, ..., 0.03, 0, 3.0]], dtype=object)

# %%
# Initialzing empty lists to append all model's name and corresponding name
acc = []
model = []

# %%
from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(Xtrain,Ytrain)

predicted_values = DecisionTree.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
# Out:
# DecisionTrees's Accuracy is:  90.68602904356536
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      1557
#            1       0.89      0.65      0.76       440
#
#     accuracy                           0.91      1997
#    macro avg       0.90      0.82      0.85      1997
# weighted avg       0.91      0.91      0.90      1997

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(DecisionTree, loan_dfx, loan_dfy,cv=5)
score
# Out:
# array([0.9118678 , 0.92034068, 0.90180361, 0.91132265, 0.90981964])

# %%
# Gausian Naive Bayes
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(Xtrain,Ytrain)

predicted_values = NaiveBayes.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# Naive Bayes's Accuracy is:  0.8347521281922884
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      1557
#            1       0.70      0.44      0.54       440
#
#     accuracy                           0.83      1997
#    macro avg       0.78      0.69      0.72      1997
# weighted avg       0.82      0.83      0.82      1997

# %%
# SVM
from sklearn.svm import SVC
# data normalization with sklearn
from sklearn.preprocessing import MinMaxScaler
# fit scaler on training data
norm = MinMaxScaler().fit(Xtrain)
X_train_norm = norm.transform(Xtrain)
# transform testing dataabs
X_test_norm = norm.transform(Xtest)
SVM = SVC(kernel='poly', degree=3, C=1)
SVM.fit(X_train_norm,Ytrain)
predicted_values = SVM.predict(X_test_norm)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# SVM's Accuracy is:  0.8793189784677016
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      1557
#            1       0.88      0.53      0.66       440
#
#     accuracy                           0.88      1997
#    macro avg       0.88      0.75      0.79      1997
# weighted avg       0.88      0.88      0.87      1997

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

LogReg = LogisticRegression(random_state=2)

LogReg.fit(Xtrain,Ytrain)

predicted_values = LogReg.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# Logistic Regression's Accuracy is:  0.800200300450676
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.88      1557
#            1       0.69      0.17      0.27       440
#
#     accuracy                           0.80      1997
#    macro avg       0.75      0.57      0.58      1997
# weighted avg       0.78      0.80      0.75      1997

# %%
# RF
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(Xtrain,Ytrain)

predicted_values = RF.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('RF')
print("RF's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# RF's Accuracy is:  0.9173760640961443
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      1557
#            1       0.94      0.66      0.78       440
#
#     accuracy                           0.92      1997
#    macro avg       0.93      0.83      0.86      1997
# weighted avg       0.92      0.92      0.91      1997

# %%
import xgboost as xgb
XB = xgb.XGBClassifier()
XB.fit(Xtrain,Ytrain)

predicted_values = XB.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('XGBoost')
print("XGBoost's Accuracy is: ", x)
# Out:
# XGBoost's Accuracy is:  0.9228843264897346

# %% [markdown]
# # Aritificial Neural Networks

# %%
# feature scaling is a must for deep learning...we must just scale every column..even if they have 1/0/short range values
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Xtrain = sc.fit_transform(Xtrain)
Xtest = sc.transform(Xtest)# dont fit here....it must be fitted to train range
# cuz later u have to transform input and for that gotta us ethis same sc

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
ANN = Sequential()

# adding the first input layer and the first hidden layer
ANN.add(Dense(11, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
ANN.add(Dropout(rate = 0.1))
ANN.add(BatchNormalization())

# adding the third hidden layer
ANN.add(Dense(8, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
ANN.add(Dropout(rate = 0.1))
ANN.add(BatchNormalization())

# adding the output layer
ANN.add(Dense(1, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
ANN.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = ANN.fit(Xtrain, Ytrain, validation_split = 0.20, validation_data = (Xtest, Ytest), epochs = 100)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 2s 4ms/step - loss: 0.5789 - accuracy: 0.7188 - val_loss: 0.5382 - val_accuracy: 0.7852
# Epoch 2/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4292 - accuracy: 0.8320 - val_loss: 0.4119 - val_accuracy: 0.8478
# Epoch 3/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3836 - accuracy: 0.8390 - val_loss: 0.3530 - val_accuracy: 0.8610
# Epoch 4/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3666 - accuracy: 0.8469 - val_loss: 0.3415 - val_accuracy: 0.8622
# Epoch 5/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3554 - accuracy: 0.8520 - val_loss: 0.3293 - val_accuracy: 0.8635
# Epoch 6/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3527 - accuracy: 0.8547 - val_loss: 0.3276 - val_accuracy: 0.8723
# Epoch 7/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3490 - accuracy: 0.8545 - val_loss: 0.3189 - val_accuracy: 0.8773
# Epoch 8/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3488 - accuracy: 0.8547 - val_loss: 0.3192 - val_accuracy: 0.8785
# Epoch 9/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3472 - accuracy: 0.8555 - val_loss: 0.3197 - val_accuracy: 0.8741
# Epoch 10/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3426 - accuracy: 0.8594 - val_loss: 0.3298 - val_accuracy: 0.8654
# Epoch 11/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3416 - accuracy: 0.8621 - val_loss: 0.3154 - val_accuracy: 0.8710
# Epoch 12/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3446 - accuracy: 0.8567 - val_loss: 0.3246 - val_accuracy: 0.8685
# Epoch 13/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3429 - accuracy: 0.8591 - val_loss: 0.3200 - val_accuracy: 0.8723
# Epoch 14/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3428 - accuracy: 0.8625 - val_loss: 0.3216 - val_accuracy: 0.8716
# Epoch 15/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3359 - accuracy: 0.8643 - val_loss: 0.3246 - val_accuracy: 0.8779
# Epoch 16/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3391 - accuracy: 0.8572 - val_loss: 0.3101 - val_accuracy: 0.8835
# Epoch 17/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3370 - accuracy: 0.8622 - val_loss: 0.3130 - val_accuracy: 0.8760
# Epoch 18/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3376 - accuracy: 0.8602 - val_loss: 0.3109 - val_accuracy: 0.8804
# Epoch 19/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3325 - accuracy: 0.8671 - val_loss: 0.3240 - val_accuracy: 0.8691
# Epoch 20/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8643 - val_loss: 0.3114 - val_accuracy: 0.8785
# Epoch 21/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3312 - accuracy: 0.8643 - val_loss: 0.3179 - val_accuracy: 0.8791
# Epoch 22/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3322 - accuracy: 0.8657 - val_loss: 0.3122 - val_accuracy: 0.8766
# Epoch 23/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3281 - accuracy: 0.8680 - val_loss: 0.3117 - val_accuracy: 0.8785
# Epoch 24/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3272 - accuracy: 0.8664 - val_loss: 0.3079 - val_accuracy: 0.8873
# Epoch 25/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3255 - accuracy: 0.8713 - val_loss: 0.3022 - val_accuracy: 0.8829
# Epoch 26/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3281 - accuracy: 0.8674 - val_loss: 0.3094 - val_accuracy: 0.8810
# Epoch 27/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3267 - accuracy: 0.8718 - val_loss: 0.3076 - val_accuracy: 0.8835
# Epoch 28/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3197 - accuracy: 0.8736 - val_loss: 0.3036 - val_accuracy: 0.8879
# Epoch 29/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3226 - accuracy: 0.8707 - val_loss: 0.3102 - val_accuracy: 0.8854
# Epoch 30/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 0.8713 - val_loss: 0.3022 - val_accuracy: 0.8854
# Epoch 31/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3232 - accuracy: 0.8721 - val_loss: 0.3000 - val_accuracy: 0.8879
# Epoch 32/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3224 - accuracy: 0.8741 - val_loss: 0.2962 - val_accuracy: 0.8917
# Epoch 33/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3228 - accuracy: 0.8694 - val_loss: 0.3035 - val_accuracy: 0.8817
# Epoch 34/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3260 - accuracy: 0.8705 - val_loss: 0.3109 - val_accuracy: 0.8829
# Epoch 35/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3216 - accuracy: 0.8722 - val_loss: 0.3096 - val_accuracy: 0.8848
# Epoch 36/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3268 - accuracy: 0.8697 - val_loss: 0.2974 - val_accuracy: 0.8860
# Epoch 37/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3244 - accuracy: 0.8710 - val_loss: 0.2977 - val_accuracy: 0.8917
# Epoch 38/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3198 - accuracy: 0.8771 - val_loss: 0.2953 - val_accuracy: 0.8917
# Epoch 39/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3259 - accuracy: 0.8732 - val_loss: 0.3012 - val_accuracy: 0.8885
# Epoch 40/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3272 - accuracy: 0.8700 - val_loss: 0.2996 - val_accuracy: 0.8898
# Epoch 41/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3143 - accuracy: 0.8773 - val_loss: 0.3038 - val_accuracy: 0.8929
# Epoch 42/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3206 - accuracy: 0.8751 - val_loss: 0.2899 - val_accuracy: 0.8942
# Epoch 43/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3175 - accuracy: 0.8762 - val_loss: 0.3077 - val_accuracy: 0.8879
# Epoch 44/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3158 - accuracy: 0.8749 - val_loss: 0.2963 - val_accuracy: 0.8986
# Epoch 45/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3245 - accuracy: 0.8719 - val_loss: 0.2992 - val_accuracy: 0.8954
# Epoch 46/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3149 - accuracy: 0.8762 - val_loss: 0.2936 - val_accuracy: 0.8998
# Epoch 47/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8754 - val_loss: 0.2967 - val_accuracy: 0.8942
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3151 - accuracy: 0.8776 - val_loss: 0.2952 - val_accuracy: 0.8954
# Epoch 49/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3172 - accuracy: 0.8782 - val_loss: 0.2957 - val_accuracy: 0.8917
# Epoch 50/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3152 - accuracy: 0.8799 - val_loss: 0.2940 - val_accuracy: 0.8904
# Epoch 51/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3163 - accuracy: 0.8773 - val_loss: 0.2953 - val_accuracy: 0.8904
# Epoch 52/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3187 - accuracy: 0.8799 - val_loss: 0.2932 - val_accuracy: 0.9017
# Epoch 53/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3107 - accuracy: 0.8823 - val_loss: 0.3055 - val_accuracy: 0.8879
# Epoch 54/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3195 - accuracy: 0.8757 - val_loss: 0.2964 - val_accuracy: 0.8936
# Epoch 55/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3201 - accuracy: 0.8790 - val_loss: 0.2904 - val_accuracy: 0.8967
# Epoch 56/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3177 - accuracy: 0.8768 - val_loss: 0.3023 - val_accuracy: 0.8910
# Epoch 57/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3200 - accuracy: 0.8724 - val_loss: 0.2980 - val_accuracy: 0.8948
# Epoch 58/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3188 - accuracy: 0.8754 - val_loss: 0.2995 - val_accuracy: 0.8910
# Epoch 59/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3157 - accuracy: 0.8799 - val_loss: 0.2926 - val_accuracy: 0.8954
# Epoch 60/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3109 - accuracy: 0.8785 - val_loss: 0.2955 - val_accuracy: 0.8948
# Epoch 61/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3164 - accuracy: 0.8807 - val_loss: 0.3029 - val_accuracy: 0.8942
# Epoch 62/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3202 - accuracy: 0.8799 - val_loss: 0.2933 - val_accuracy: 0.8942
# Epoch 63/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3161 - accuracy: 0.8796 - val_loss: 0.2921 - val_accuracy: 0.8986
# Epoch 64/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3151 - accuracy: 0.8796 - val_loss: 0.2936 - val_accuracy: 0.8979
# Epoch 65/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3179 - accuracy: 0.8758 - val_loss: 0.2952 - val_accuracy: 0.8948
# Epoch 66/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3121 - accuracy: 0.8799 - val_loss: 0.2883 - val_accuracy: 0.9011
# Epoch 67/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3111 - accuracy: 0.8826 - val_loss: 0.2953 - val_accuracy: 0.8979
# Epoch 68/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3096 - accuracy: 0.8807 - val_loss: 0.2946 - val_accuracy: 0.8936
# Epoch 69/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3132 - accuracy: 0.8813 - val_loss: 0.2982 - val_accuracy: 0.8892
# Epoch 70/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.8830 - val_loss: 0.2874 - val_accuracy: 0.8961
# Epoch 71/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3143 - accuracy: 0.8805 - val_loss: 0.2988 - val_accuracy: 0.8910
# Epoch 72/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3130 - accuracy: 0.8783 - val_loss: 0.2976 - val_accuracy: 0.8879
# Epoch 73/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3130 - accuracy: 0.8749 - val_loss: 0.2931 - val_accuracy: 0.8898
# Epoch 74/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3160 - accuracy: 0.8798 - val_loss: 0.2898 - val_accuracy: 0.8986
# Epoch 75/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3100 - accuracy: 0.8815 - val_loss: 0.2926 - val_accuracy: 0.8923
# Epoch 76/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3061 - accuracy: 0.8838 - val_loss: 0.3002 - val_accuracy: 0.8854
# Epoch 77/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.3089 - accuracy: 0.8801 - val_loss: 0.2970 - val_accuracy: 0.8910
# Epoch 78/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3124 - accuracy: 0.8773 - val_loss: 0.3017 - val_accuracy: 0.8867
# Epoch 79/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3185 - accuracy: 0.8768 - val_loss: 0.2977 - val_accuracy: 0.8867
# Epoch 80/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3083 - accuracy: 0.8829 - val_loss: 0.2915 - val_accuracy: 0.8942
# Epoch 81/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3082 - accuracy: 0.8827 - val_loss: 0.2999 - val_accuracy: 0.8904
# Epoch 82/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3117 - accuracy: 0.8838 - val_loss: 0.2947 - val_accuracy: 0.8917
# Epoch 83/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3139 - accuracy: 0.8791 - val_loss: 0.2935 - val_accuracy: 0.8954
# Epoch 84/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3168 - accuracy: 0.8815 - val_loss: 0.2953 - val_accuracy: 0.8917
# Epoch 85/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3080 - accuracy: 0.8801 - val_loss: 0.2937 - val_accuracy: 0.8917
# Epoch 86/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3126 - accuracy: 0.8798 - val_loss: 0.2932 - val_accuracy: 0.8898
# Epoch 87/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3044 - accuracy: 0.8805 - val_loss: 0.2915 - val_accuracy: 0.8954
# Epoch 88/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3125 - accuracy: 0.8829 - val_loss: 0.2926 - val_accuracy: 0.8986
# Epoch 89/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3105 - accuracy: 0.8791 - val_loss: 0.2881 - val_accuracy: 0.8986
# Epoch 90/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3111 - accuracy: 0.8824 - val_loss: 0.2916 - val_accuracy: 0.8967
# Epoch 91/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3102 - accuracy: 0.8791 - val_loss: 0.2898 - val_accuracy: 0.8942
# Epoch 92/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3071 - accuracy: 0.8816 - val_loss: 0.2946 - val_accuracy: 0.8923
# Epoch 93/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3071 - accuracy: 0.8852 - val_loss: 0.2897 - val_accuracy: 0.9011
# Epoch 94/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3080 - accuracy: 0.8780 - val_loss: 0.2914 - val_accuracy: 0.8892
# Epoch 95/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3092 - accuracy: 0.8834 - val_loss: 0.2861 - val_accuracy: 0.8954
# Epoch 96/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3054 - accuracy: 0.8846 - val_loss: 0.2891 - val_accuracy: 0.8998
# Epoch 97/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3068 - accuracy: 0.8783 - val_loss: 0.2949 - val_accuracy: 0.8936
# Epoch 98/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3081 - accuracy: 0.8826 - val_loss: 0.2906 - val_accuracy: 0.8986
# Epoch 99/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3060 - accuracy: 0.8855 - val_loss: 0.2884 - val_accuracy: 0.8961
# Epoch 100/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3099 - accuracy: 0.8813 - val_loss: 0.2959 - val_accuracy: 0.8917

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training Loss')
sns.lineplot(epoch, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Accuracy Comparision

# %%
acc.append(0.8917)

# %%
model.append('ANN')

# %%
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')

# %%
accuracy_models = dict(zip(model, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# Decision Tree --> 0.9068602904356535
# Naive Bayes --> 0.8347521281922884
# SVM --> 0.8793189784677016
# Logistic Regression --> 0.800200300450676
# RF --> 0.9173760640961443
# XGBoost --> 0.9178768152228343
# ANN --> 0.8917

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0-cp37-cp37m-manylinux2010_x86_64.whl (564 kB)
#      |████████████████████████████████| 564 kB 4.4 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.40.0 slicer-0.0.7

# %%
import shap

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(XB)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(Xtest)

# Make plot. Index of [1] is explained in text below.
shap.summary_plot(shap_values, Xtest, feature_names = ['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length'])
